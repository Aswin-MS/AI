# %% [markdown]
# ## **Face Detection**

# %%
import cv2
import matplotlib.pyplot as plt

# %%
img=cv2.imread('img/3face.jpg')
img
# Out:
# array([[[ 40,  30,  30],
#         [ 40,  30,  30],
#         [ 40,  30,  30],
#         ...,
#         [221, 212, 215],
#         [221, 212, 215],
#         [221, 212, 215]],
#
#        [[ 40,  30,  30],
#         [ 40,  30,  30],
#         [ 40,  30,  30],
#         ...,
#         [221, 212, 215],
#         [221, 212, 215],
#         [221, 212, 215]],
#
#        [[ 40,  30,  30],
#         [ 40,  30,  30],
#         [ 40,  30,  30],
#         ...,
#         [221, 212, 215],
#         [221, 212, 215],
#         [221, 212, 215]],
#
#        ...,
#
#        [[ 94,  85, 128],
#         [ 99,  90, 133],
#         [104,  95, 138],
#         ...,
#         [ 50,  49,  91],
#         [ 48,  47,  89],
#         [ 47,  46,  88]],
#
#        [[ 98,  88, 134],
#         [102,  92, 138],
#         [106,  96, 142],
#         ...,
#         [ 48,  47,  89],
#         [ 46,  45,  87],
#         [ 44,  43,  85]],
#
#        [[101,  91, 137],
#         [105,  95, 141],
#         [107,  97, 143],
#         ...,
#         [ 59,  58, 100],
#         [ 55,  54,  96],
#         [ 52,  51,  93]]], shape=(168, 300, 3), dtype=uint8)

# %%
conv_img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(conv_img)

# %%
face_cas=cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
faces=face_cas.detectMultiScale(conv_img,minNeighbors=7)
faces
# Out:
# array([[118,  34,  60,  60],
#        [ 14,  37,  62,  62],
#        [218,  31,  63,  63]], dtype=int32)

# %%
for x,y,w,h in faces:
    cv2.rectangle(conv_img,(x,y),(x+w,y+h),(255,0,0),1)
plt.imshow(conv_img)
