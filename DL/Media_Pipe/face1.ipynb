# %%
import mediapipe as mp
import cv2

# %%
mp_face=mp.solutions.face_detection
mp_draw=mp.solutions.drawing_utils

# %%
data=mp_face.FaceDetection()

# %%
video=cv2.VideoCapture(0)
while True:
    succ,img=video.read()
    frame=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    result=data.process(frame)
    print(result.detections)
    if result.detections: #if hand is detected
        for x in result.detections:
            mp_draw.draw_detection(img,x)

    cv2.imshow('Webcam',img)
    if cv2.waitKey(1) & 0XFF==ord('q'):
        break
video.release()
cv2.destroyAllWindows()
# Out:
# [label_id: 0
# score: 0.894481182
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.249951914
#     ymin: 0.458346
#     width: 0.313190818
#     height: 0.41756016
#   }
#   relative_keypoints {
#     x: 0.319256127
#     y: 0.610276
#   }
#   relative_keypoints {
#     x: 0.443894029
#     y: 0.561965883
#   }
#   relative_keypoints {
#     x: 0.390462875
#     y: 0.697934568
#   }
#   relative_keypoints {
#     x: 0.412958
#     y: 0.774814069
#   }
#   relative_keypoints {
#     x: 0.280092657
#     y: 0.655566692
#   }
#   relative_keypoints {
#     x: 0.540734947
#     y: 0.555641353
#   }
# }
# ]
# [label_id: 0
# score: 0.918474615
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.278054178
#     ymin: 0.442314506
#     width: 0.30265677
#     height: 0.403514326
#   }
#   relative_keypoints {
#     x: 0.335974097
#     y: 0.5991714
#   }
#   relative_keypoints {
#     x: 0.453972667
#     y: 0.552751243
#   }
#   relative_keypoints {
#     x: 0.395564526
#     y: 0.69173497
#   }
#   relative_keypoints {
#     x: 0.421386391
#     y: 0.757759154
#   }
#   relative_keypoints {
#     x: 0.311848402
#     y: 0.627788365
#   }
#   relative_keypoints {
#     x: 0.560548127
#     y: 0.531183422
#   }
# }
# ]
# [label_id: 0
# score: 0.941730559
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.282928139
#     ymin: 0.444670498
#     width: 0.301317841
#     height: 0.401733756
#   }
#   relative_keypoints {
#     x: 0.342606634
#     y: 0.598480523
#   }
#   relative_keypoints {
#     x: 0.46316117
#     y: 0.551578701
#   }
#   relative_keypoints {
#     x: 0.406442821
#     y: 0.687516868
#   }
#   relative_keypoints {
#     x: 0.430531889
#     y: 0.753809
#   }
#   relative_keypoints {
#     x: 0.31151253
#     y: 0.632662356
#   }
#   relative_keypoints {
#     x: 0.565011561
#     y: 0.535581887
#   }
# }
# ]
# [label_id: 0
# score: 0.941730559
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.282928139
#     ymin: 0.444670498
#     width: 0.301317841
#     height: 0.401733756
#   }
#   relative_keypoints {
#     x: 0.342606634
#     y: 0.598480523
#   }
#   relative_keypoints {
#     x: 0.46316117
#     y: 0.551578701
#   }
#   relative_keypoints {
#     x: 0.406442821
#     y: 0.687516868
#   }
#   relative_keypoints {
#     x: 0.430531889
#     y: 0.753809
#   }
#   relative_keypoints {
#     x: 0.31151253
#     y: 0.632662356
#   }
#   relative_keypoints {
#     x: 0.565011561
#     y: 0.535581887
#   }
# }
# ]
# [label_id: 0
# score: 0.93432647
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.282777429
#     ymin: 0.433927238
#     width: 0.308013737
#     height: 0.410663366
#   }
#   relative_keypoints {
#     x: 0.347469836
#     y: 0.583416402
#   }
#   relative_keypoints {
#     x: 0.475939691
#     y: 0.542213857
#   }
#   relative_keypoints {
#     x: 0.416838914
#     y: 0.67411691
#   }
#   relative_keypoints {
#     x: 0.437069297
#     y: 0.745321095
#   }
#   relative_keypoints {
#     x: 0.306006759
#     y: 0.623405
#   }
#   relative_keypoints {
#     x: 0.573952198
#     y: 0.538268268
#   }
# }
# ]
# [label_id: 0
# score: 0.93432647
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.282777429
#     ymin: 0.433927238
#     width: 0.308013737
#     height: 0.410663366
#   }
#   relative_keypoints {
#     x: 0.347469836
#     y: 0.583416402
#   }
#   relative_keypoints {
#     x: 0.475939691
#     y: 0.542213857
#   }
#   relative_keypoints {
#     x: 0.416838914
#     y: 0.67411691
#   }
#   relative_keypoints {
#     x: 0.437069297
#     y: 0.745321095
#   }
#   relative_keypoints {
#     x: 0.306006759
#     y: 0.623405
#   }
#   relative_keypoints {
#     x: 0.573952198
#     y: 0.538268268
#   }
# }
# ]
# [label_id: 0
# score: 0.943599045
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.2826
#     ymin: 0.42524302
#     width: 0.314631462
#     height: 0.419487417
#   }
#   relative_keypoints {
#     x: 0.348845243
#     y: 0.573309422
#   }
#   relative_keypoints {
#     x: 0.481633216
#     y: 0.541238487
#   }
#   relative_keypoints {
#     x: 0.415957034
#     y: 0.673395097
#   }
#   relative_keypoints {
#     x: 0.433615357
#     y: 0.745034695
#   }
#   relative_keypoints {
#     x: 0.305975
#     y: 0.607447624
#   }
#   relative_keypoints {
#     x: 0.580544
#     y: 0.54125458
#   }
# }
# ]
# [label_id: 0
# score: 0.943599045
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.2826
#     ymin: 0.42524302
#     width: 0.314631462
#     height: 0.419487417
#   }
#   relative_keypoints {
#     x: 0.348845243
#     y: 0.573309422
#   }
#   relative_keypoints {
#     x: 0.481633216
#     y: 0.541238487
#   }
#   relative_keypoints {
#     x: 0.415957034
#     y: 0.673395097
#   }
#   relative_keypoints {
#     x: 0.433615357
#     y: 0.745034695
#   }
#   relative_keypoints {
#     x: 0.305975
#     y: 0.607447624
#   }
#   relative_keypoints {
#     x: 0.580544
#     y: 0.54125458
#   }
# }
# ]
# [label_id: 0
# score: 0.945123494
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.28776589
#     ymin: 0.425095499
#     width: 0.312122732
#     height: 0.416142
#   }
#   relative_keypoints {
#     x: 0.356153548
#     y: 0.563376963
#   }
#   relative_keypoints {
#     x: 0.487206191
#     y: 0.54138726
#   }
#   relative_keypoints {
#     x: 0.419138074
#     y: 0.666200638
#   }
#   relative_keypoints {
#     x: 0.433363765
#     y: 0.740430653
#   }
#   relative_keypoints {
#     x: 0.311632693
#     y: 0.597299814
#   }
#   relative_keypoints {
#     x: 0.582365453
#     y: 0.551363
#   }
# }
# ]
# [label_id: 0
# score: 0.945123494
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.28776589
#     ymin: 0.425095499
#     width: 0.312122732
#     height: 0.416142
#   }
#   relative_keypoints {
#     x: 0.356153548
#     y: 0.563376963
#   }
#   relative_keypoints {
#     x: 0.487206191
#     y: 0.54138726
#   }
#   relative_keypoints {
#     x: 0.419138074
#     y: 0.666200638
#   }
#   relative_keypoints {
#     x: 0.433363765
#     y: 0.740430653
#   }
#   relative_keypoints {
#     x: 0.311632693
#     y: 0.597299814
#   }
#   relative_keypoints {
#     x: 0.582365453
#     y: 0.551363
#   }
# }
# ]
# [label_id: 0
# score: 0.947892189
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.303973258
#     ymin: 0.428666115
#     width: 0.294297159
#     height: 0.392382383
#   }
#   relative_keypoints {
#     x: 0.368952513
#     y: 0.556018114
#   }
#   relative_keypoints {
#     x: 0.494490027
#     y: 0.536815166
#   }
#   relative_keypoints {
#     x: 0.428745449
#     y: 0.650389493
#   }
#   relative_keypoints {
#     x: 0.441081911
#     y: 0.72207284
#   }
#   relative_keypoints {
#     x: 0.324477822
#     y: 0.590093374
#   }
#   relative_keypoints {
#     x: 0.584832668
#     y: 0.551022947
#   }
# }
# ]
# [label_id: 0
# score: 0.947892189
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.303973258
#     ymin: 0.428666115
#     width: 0.294297159
#     height: 0.392382383
#   }
#   relative_keypoints {
#     x: 0.368952513
#     y: 0.556018114
#   }
#   relative_keypoints {
#     x: 0.494490027
#     y: 0.536815166
#   }
#   relative_keypoints {
#     x: 0.428745449
#     y: 0.650389493
#   }
#   relative_keypoints {
#     x: 0.441081911
#     y: 0.72207284
#   }
#   relative_keypoints {
#     x: 0.324477822
#     y: 0.590093374
#   }
#   relative_keypoints {
#     x: 0.584832668
#     y: 0.551022947
#   }
# }
# ]
# [label_id: 0
# score: 0.948426664
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.308479488
#     ymin: 0.42670238
#     width: 0.300495982
#     height: 0.400646806
#   }
#   relative_keypoints {
#     x: 0.379412562
#     y: 0.552442849
#   }
#   relative_keypoints {
#     x: 0.507364213
#     y: 0.539341629
#   }
#   relative_keypoints {
#     x: 0.439981639
#     y: 0.65240556
#   }
#   relative_keypoints {
#     x: 0.448934883
#     y: 0.725725412
#   }
#   relative_keypoints {
#     x: 0.328764707
#     y: 0.584429562
#   }
#   relative_keypoints {
#     x: 0.593523
#     y: 0.558276176
#   }
# }
# ]
# [label_id: 0
# score: 0.948426664
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.308479488
#     ymin: 0.42670238
#     width: 0.300495982
#     height: 0.400646806
#   }
#   relative_keypoints {
#     x: 0.379412562
#     y: 0.552442849
#   }
#   relative_keypoints {
#     x: 0.507364213
#     y: 0.539341629
#   }
#   relative_keypoints {
#     x: 0.439981639
#     y: 0.65240556
#   }
#   relative_keypoints {
#     x: 0.448934883
#     y: 0.725725412
#   }
#   relative_keypoints {
#     x: 0.328764707
#     y: 0.584429562
#   }
#   relative_keypoints {
#     x: 0.593523
#     y: 0.558276176
#   }
# }
# ]
# [label_id: 0
# score: 0.936463714
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.315657824
#     ymin: 0.425542414
#     width: 0.301192075
#     height: 0.40157342
#   }
#   relative_keypoints {
#     x: 0.383145958
#     y: 0.555481613
#   }
#   relative_keypoints {
#     x: 0.511754632
#     y: 0.538992465
#   }
#   relative_keypoints {
#     x: 0.443733245
#     y: 0.655638397
#   }
#   relative_keypoints {
#     x: 0.455507666
#     y: 0.72812891
#   }
#   relative_keypoints {
#     x: 0.336353
#     y: 0.586712599
#   }
#   relative_keypoints {
#     x: 0.602204859
#     y: 0.551975071
#   }
# }
# ]
# [label_id: 0
# score: 0.936463714
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.315657824
#     ymin: 0.425542414
#     width: 0.301192075
#     height: 0.40157342
#   }
#   relative_keypoints {
#     x: 0.383145958
#     y: 0.555481613
#   }
#   relative_keypoints {
#     x: 0.511754632
#     y: 0.538992465
#   }
#   relative_keypoints {
#     x: 0.443733245
#     y: 0.655638397
#   }
#   relative_keypoints {
#     x: 0.455507666
#     y: 0.72812891
#   }
#   relative_keypoints {
#     x: 0.336353
#     y: 0.586712599
#   }
#   relative_keypoints {
#     x: 0.602204859
#     y: 0.551975071
#   }
# }
# ]
# [label_id: 0
# score: 0.934381068
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.31607005
#     ymin: 0.423767745
#     width: 0.305819243
#     height: 0.407743037
#   }
#   relative_keypoints {
#     x: 0.385525912
#     y: 0.553432882
#   }
#   relative_keypoints {
#     x: 0.517435253
#     y: 0.536077678
#   }
#   relative_keypoints {
#     x: 0.449496567
#     y: 0.653054059
#   }
#   relative_keypoints {
#     x: 0.46114105
#     y: 0.728531301
#   }
#   relative_keypoints {
#     x: 0.335102379
#     y: 0.589660227
#   }
#   relative_keypoints {
#     x: 0.607347786
#     y: 0.552686393
#   }
# }
# ]
# [label_id: 0
# score: 0.934381068
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.31607005
#     ymin: 0.423767745
#     width: 0.305819243
#     height: 0.407743037
#   }
#   relative_keypoints {
#     x: 0.385525912
#     y: 0.553432882
#   }
#   relative_keypoints {
#     x: 0.517435253
#     y: 0.536077678
#   }
#   relative_keypoints {
#     x: 0.449496567
#     y: 0.653054059
#   }
#   relative_keypoints {
#     x: 0.46114105
#     y: 0.728531301
#   }
#   relative_keypoints {
#     x: 0.335102379
#     y: 0.589660227
#   }
#   relative_keypoints {
#     x: 0.607347786
#     y: 0.552686393
#   }
# }
# ]
# [label_id: 0
# score: 0.925452232
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.318159133
#     ymin: 0.422898
#     width: 0.308120638
#     height: 0.410811543
#   }
#   relative_keypoints {
#     x: 0.390467435
#     y: 0.548643827
#   }
#   relative_keypoints {
#     x: 0.523702502
#     y: 0.539529085
#   }
#   relative_keypoints {
#     x: 0.452047706
#     y: 0.653058708
#   }
#   relative_keypoints {
#     x: 0.460484415
#     y: 0.730298519
#   }
#   relative_keypoints {
#     x: 0.336971849
#     y: 0.582069457
#   }
#   relative_keypoints {
#     x: 0.611673534
#     y: 0.56267482
#   }
# }
# ]
# [label_id: 0
# score: 0.925452232
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.318159133
#     ymin: 0.422898
#     width: 0.308120638
#     height: 0.410811543
#   }
#   relative_keypoints {
#     x: 0.390467435
#     y: 0.548643827
#   }
#   relative_keypoints {
#     x: 0.523702502
#     y: 0.539529085
#   }
#   relative_keypoints {
#     x: 0.452047706
#     y: 0.653058708
#   }
#   relative_keypoints {
#     x: 0.460484415
#     y: 0.730298519
#   }
#   relative_keypoints {
#     x: 0.336971849
#     y: 0.582069457
#   }
#   relative_keypoints {
#     x: 0.611673534
#     y: 0.56267482
#   }
# }
# ]
# [label_id: 0
# score: 0.915144503
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.320549428
#     ymin: 0.420571446
#     width: 0.310527325
#     height: 0.414020121
#   }
#   relative_keypoints {
#     x: 0.390111655
#     y: 0.549721062
#   }
#   relative_keypoints {
#     x: 0.524162412
#     y: 0.538422048
#   }
#   relative_keypoints {
#     x: 0.450568467
#     y: 0.655998707
#   }
#   relative_keypoints {
#     x: 0.460879564
#     y: 0.732562721
#   }
#   relative_keypoints {
#     x: 0.340805143
#     y: 0.582188368
#   }
#   relative_keypoints {
#     x: 0.616495907
#     y: 0.558159113
#   }
# }
# ]
# [label_id: 0
# score: 0.915144503
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.320549428
#     ymin: 0.420571446
#     width: 0.310527325
#     height: 0.414020121
#   }
#   relative_keypoints {
#     x: 0.390111655
#     y: 0.549721062
#   }
#   relative_keypoints {
#     x: 0.524162412
#     y: 0.538422048
#   }
#   relative_keypoints {
#     x: 0.450568467
#     y: 0.655998707
#   }
#   relative_keypoints {
#     x: 0.460879564
#     y: 0.732562721
#   }
#   relative_keypoints {
#     x: 0.340805143
#     y: 0.582188368
#   }
#   relative_keypoints {
#     x: 0.616495907
#     y: 0.558159113
#   }
# }
# ]
# [label_id: 0
# score: 0.928762376
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.320742309
#     ymin: 0.414040923
#     width: 0.313893318
#     height: 0.418500602
#   }
#   relative_keypoints {
#     x: 0.39492318
#     y: 0.542098224
#   }
#   relative_keypoints {
#     x: 0.528585255
#     y: 0.537601709
#   }
#   relative_keypoints {
#     x: 0.453871518
#     y: 0.655387163
#   }
#   relative_keypoints {
#     x: 0.461422473
#     y: 0.731319964
#   }
#   relative_keypoints {
#     x: 0.342558324
#     y: 0.569823265
#   }
#   relative_keypoints {
#     x: 0.618022621
#     y: 0.558699429
#   }
# }
# ]
# [label_id: 0
# score: 0.928762376
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.320742309
#     ymin: 0.414040923
#     width: 0.313893318
#     height: 0.418500602
#   }
#   relative_keypoints {
#     x: 0.39492318
#     y: 0.542098224
#   }
#   relative_keypoints {
#     x: 0.528585255
#     y: 0.537601709
#   }
#   relative_keypoints {
#     x: 0.453871518
#     y: 0.655387163
#   }
#   relative_keypoints {
#     x: 0.461422473
#     y: 0.731319964
#   }
#   relative_keypoints {
#     x: 0.342558324
#     y: 0.569823265
#   }
#   relative_keypoints {
#     x: 0.618022621
#     y: 0.558699429
#   }
# }
# ]
# [label_id: 0
# score: 0.914634526
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.323130906
#     ymin: 0.413192451
#     width: 0.314727843
#     height: 0.4196136
#   }
#   relative_keypoints {
#     x: 0.401355624
#     y: 0.543707311
#   }
#   relative_keypoints {
#     x: 0.535743594
#     y: 0.5466187
#   }
#   relative_keypoints {
#     x: 0.460200965
#     y: 0.664832592
#   }
#   relative_keypoints {
#     x: 0.464877158
#     y: 0.737090111
#   }
#   relative_keypoints {
#     x: 0.344048798
#     y: 0.561096489
#   }
#   relative_keypoints {
#     x: 0.620086
#     y: 0.562598
#   }
# }
# ]
# [label_id: 0
# score: 0.914634526
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.323130906
#     ymin: 0.413192451
#     width: 0.314727843
#     height: 0.4196136
#   }
#   relative_keypoints {
#     x: 0.401355624
#     y: 0.543707311
#   }
#   relative_keypoints {
#     x: 0.535743594
#     y: 0.5466187
#   }
#   relative_keypoints {
#     x: 0.460200965
#     y: 0.664832592
#   }
#   relative_keypoints {
#     x: 0.464877158
#     y: 0.737090111
#   }
#   relative_keypoints {
#     x: 0.344048798
#     y: 0.561096489
#   }
#   relative_keypoints {
#     x: 0.620086
#     y: 0.562598
#   }
# }
# ]
# [label_id: 0
# score: 0.917567432
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.325588554
#     ymin: 0.408806145
#     width: 0.314831883
#     height: 0.419752
#   }
#   relative_keypoints {
#     x: 0.407936245
#     y: 0.535451114
#   }
#   relative_keypoints {
#     x: 0.54248327
#     y: 0.540725887
#   }
#   relative_keypoints {
#     x: 0.468532145
#     y: 0.655040741
#   }
#   relative_keypoints {
#     x: 0.47102955
#     y: 0.729777336
#   }
#   relative_keypoints {
#     x: 0.344998807
#     y: 0.555230856
#   }
#   relative_keypoints {
#     x: 0.621976435
#     y: 0.562230289
#   }
# }
# ]
# [label_id: 0
# score: 0.917567432
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.325588554
#     ymin: 0.408806145
#     width: 0.314831883
#     height: 0.419752
#   }
#   relative_keypoints {
#     x: 0.407936245
#     y: 0.535451114
#   }
#   relative_keypoints {
#     x: 0.54248327
#     y: 0.540725887
#   }
#   relative_keypoints {
#     x: 0.468532145
#     y: 0.655040741
#   }
#   relative_keypoints {
#     x: 0.47102955
#     y: 0.729777336
#   }
#   relative_keypoints {
#     x: 0.344998807
#     y: 0.555230856
#   }
#   relative_keypoints {
#     x: 0.621976435
#     y: 0.562230289
#   }
# }
# ]
# [label_id: 0
# score: 0.937995613
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.332848549
#     ymin: 0.409420431
#     width: 0.314944625
#     height: 0.419900954
#   }
#   relative_keypoints {
#     x: 0.425801724
#     y: 0.535461187
#   }
#   relative_keypoints {
#     x: 0.557505906
#     y: 0.540840447
#   }
#   relative_keypoints {
#     x: 0.491076201
#     y: 0.654975593
#   }
#   relative_keypoints {
#     x: 0.490004569
#     y: 0.730088294
#   }
#   relative_keypoints {
#     x: 0.35213244
#     y: 0.555224895
#   }
#   relative_keypoints {
#     x: 0.62482965
#     y: 0.563145
#   }
# }
# ]
# [label_id: 0
# score: 0.937995613
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.332848549
#     ymin: 0.409420431
#     width: 0.314944625
#     height: 0.419900954
#   }
#   relative_keypoints {
#     x: 0.425801724
#     y: 0.535461187
#   }
#   relative_keypoints {
#     x: 0.557505906
#     y: 0.540840447
#   }
#   relative_keypoints {
#     x: 0.491076201
#     y: 0.654975593
#   }
#   relative_keypoints {
#     x: 0.490004569
#     y: 0.730088294
#   }
#   relative_keypoints {
#     x: 0.35213244
#     y: 0.555224895
#   }
#   relative_keypoints {
#     x: 0.62482965
#     y: 0.563145
#   }
# }
# ]
# [label_id: 0
# score: 0.92605
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.337813914
#     ymin: 0.405877233
#     width: 0.31815958
#     height: 0.424186409
#   }
#   relative_keypoints {
#     x: 0.442622095
#     y: 0.524834
#   }
#   relative_keypoints {
#     x: 0.575139463
#     y: 0.544315636
#   }
#   relative_keypoints {
#     x: 0.509791195
#     y: 0.651486635
#   }
#   relative_keypoints {
#     x: 0.501371622
#     y: 0.729769945
#   }
#   relative_keypoints {
#     x: 0.355323195
#     y: 0.539867818
#   }
#   relative_keypoints {
#     x: 0.630363107
#     y: 0.574418366
#   }
# }
# ]
# [label_id: 0
# score: 0.92605
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.337813914
#     ymin: 0.405877233
#     width: 0.31815958
#     height: 0.424186409
#   }
#   relative_keypoints {
#     x: 0.442622095
#     y: 0.524834
#   }
#   relative_keypoints {
#     x: 0.575139463
#     y: 0.544315636
#   }
#   relative_keypoints {
#     x: 0.509791195
#     y: 0.651486635
#   }
#   relative_keypoints {
#     x: 0.501371622
#     y: 0.729769945
#   }
#   relative_keypoints {
#     x: 0.355323195
#     y: 0.539867818
#   }
#   relative_keypoints {
#     x: 0.630363107
#     y: 0.574418366
#   }
# }
# ]
# [label_id: 0
# score: 0.945102274
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.351765424
#     ymin: 0.405603349
#     width: 0.31215468
#     height: 0.416178763
#   }
#   relative_keypoints {
#     x: 0.461482495
#     y: 0.522638857
#   }
#   relative_keypoints {
#     x: 0.588647842
#     y: 0.547565222
#   }
#   relative_keypoints {
#     x: 0.526352286
#     y: 0.651595414
#   }
#   relative_keypoints {
#     x: 0.513797879
#     y: 0.725080788
#   }
#   relative_keypoints {
#     x: 0.369960457
#     y: 0.528538704
#   }
#   relative_keypoints {
#     x: 0.635752797
#     y: 0.575835
#   }
# }
# ]
# [label_id: 0
# score: 0.945102274
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.351765424
#     ymin: 0.405603349
#     width: 0.31215468
#     height: 0.416178763
#   }
#   relative_keypoints {
#     x: 0.461482495
#     y: 0.522638857
#   }
#   relative_keypoints {
#     x: 0.588647842
#     y: 0.547565222
#   }
#   relative_keypoints {
#     x: 0.526352286
#     y: 0.651595414
#   }
#   relative_keypoints {
#     x: 0.513797879
#     y: 0.725080788
#   }
#   relative_keypoints {
#     x: 0.369960457
#     y: 0.528538704
#   }
#   relative_keypoints {
#     x: 0.635752797
#     y: 0.575835
#   }
# }
# ]
# [label_id: 0
# score: 0.954723358
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.360199064
#     ymin: 0.405388
#     width: 0.310367852
#     height: 0.413800418
#   }
#   relative_keypoints {
#     x: 0.474204719
#     y: 0.521038
#   }
#   relative_keypoints {
#     x: 0.599579096
#     y: 0.548844814
#   }
#   relative_keypoints {
#     x: 0.540124297
#     y: 0.650486767
#   }
#   relative_keypoints {
#     x: 0.525364697
#     y: 0.722808361
#   }
#   relative_keypoints {
#     x: 0.378535509
#     y: 0.522661924
#   }
#   relative_keypoints {
#     x: 0.641679466
#     y: 0.575974047
#   }
# }
# ]
# [label_id: 0
# score: 0.954723358
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.360199064
#     ymin: 0.405388
#     width: 0.310367852
#     height: 0.413800418
#   }
#   relative_keypoints {
#     x: 0.474204719
#     y: 0.521038
#   }
#   relative_keypoints {
#     x: 0.599579096
#     y: 0.548844814
#   }
#   relative_keypoints {
#     x: 0.540124297
#     y: 0.650486767
#   }
#   relative_keypoints {
#     x: 0.525364697
#     y: 0.722808361
#   }
#   relative_keypoints {
#     x: 0.378535509
#     y: 0.522661924
#   }
#   relative_keypoints {
#     x: 0.641679466
#     y: 0.575974047
#   }
# }
# ]
# [label_id: 0
# score: 0.950374961
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.374604225
#     ymin: 0.412048936
#     width: 0.299655676
#     height: 0.399519324
#   }
#   relative_keypoints {
#     x: 0.478182703
#     y: 0.521379054
#   }
#   relative_keypoints {
#     x: 0.601538122
#     y: 0.548176
#   }
#   relative_keypoints {
#     x: 0.538933337
#     y: 0.644224465
#   }
#   relative_keypoints {
#     x: 0.526734948
#     y: 0.716046274
#   }
#   relative_keypoints {
#     x: 0.391736627
#     y: 0.526361167
#   }
#   relative_keypoints {
#     x: 0.649870336
#     y: 0.5781129
#   }
# }
# ]
# [label_id: 0
# score: 0.950374961
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.374604225
#     ymin: 0.412048936
#     width: 0.299655676
#     height: 0.399519324
#   }
#   relative_keypoints {
#     x: 0.478182703
#     y: 0.521379054
#   }
#   relative_keypoints {
#     x: 0.601538122
#     y: 0.548176
#   }
#   relative_keypoints {
#     x: 0.538933337
#     y: 0.644224465
#   }
#   relative_keypoints {
#     x: 0.526734948
#     y: 0.716046274
#   }
#   relative_keypoints {
#     x: 0.391736627
#     y: 0.526361167
#   }
#   relative_keypoints {
#     x: 0.649870336
#     y: 0.5781129
#   }
# }
# ]
# [label_id: 0
# score: 0.955684185
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.370299
#     ymin: 0.411591
#     width: 0.308727115
#     height: 0.411612868
#   }
#   relative_keypoints {
#     x: 0.48595193
#     y: 0.525778055
#   }
#   relative_keypoints {
#     x: 0.608827472
#     y: 0.556696832
#   }
#   relative_keypoints {
#     x: 0.548658431
#     y: 0.656881034
#   }
#   relative_keypoints {
#     x: 0.532750845
#     y: 0.727412224
#   }
#   relative_keypoints {
#     x: 0.391030669
#     y: 0.523142397
#   }
#   relative_keypoints {
#     x: 0.649177372
#     y: 0.583885491
#   }
# }
# ]
# [label_id: 0
# score: 0.955684185
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.370299
#     ymin: 0.411591
#     width: 0.308727115
#     height: 0.411612868
#   }
#   relative_keypoints {
#     x: 0.48595193
#     y: 0.525778055
#   }
#   relative_keypoints {
#     x: 0.608827472
#     y: 0.556696832
#   }
#   relative_keypoints {
#     x: 0.548658431
#     y: 0.656881034
#   }
#   relative_keypoints {
#     x: 0.532750845
#     y: 0.727412224
#   }
#   relative_keypoints {
#     x: 0.391030669
#     y: 0.523142397
#   }
#   relative_keypoints {
#     x: 0.649177372
#     y: 0.583885491
#   }
# }
# ]
# [label_id: 0
# score: 0.941466749
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.37255913
#     ymin: 0.411410749
#     width: 0.31780982
#     height: 0.423722267
#   }
#   relative_keypoints {
#     x: 0.486283869
#     y: 0.52649194
#   }
#   relative_keypoints {
#     x: 0.614489317
#     y: 0.553061664
#   }
#   relative_keypoints {
#     x: 0.551745176
#     y: 0.655468702
#   }
#   relative_keypoints {
#     x: 0.538924
#     y: 0.731954873
#   }
#   relative_keypoints {
#     x: 0.394527435
#     y: 0.5355708
#   }
#   relative_keypoints {
#     x: 0.661057293
#     y: 0.586602628
#   }
# }
# ]
# [label_id: 0
# score: 0.941466749
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.37255913
#     ymin: 0.411410749
#     width: 0.31780982
#     height: 0.423722267
#   }
#   relative_keypoints {
#     x: 0.486283869
#     y: 0.52649194
#   }
#   relative_keypoints {
#     x: 0.614489317
#     y: 0.553061664
#   }
#   relative_keypoints {
#     x: 0.551745176
#     y: 0.655468702
#   }
#   relative_keypoints {
#     x: 0.538924
#     y: 0.731954873
#   }
#   relative_keypoints {
#     x: 0.394527435
#     y: 0.5355708
#   }
#   relative_keypoints {
#     x: 0.661057293
#     y: 0.586602628
#   }
# }
# ]
# [label_id: 0
# score: 0.924235
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.37715885
#     ymin: 0.41111517
#     width: 0.318116397
#     height: 0.424130499
#   }
#   relative_keypoints {
#     x: 0.493264467
#     y: 0.530955
#   }
#   relative_keypoints {
#     x: 0.621107042
#     y: 0.557777941
#   }
#   relative_keypoints {
#     x: 0.55994153
#     y: 0.664312661
#   }
#   relative_keypoints {
#     x: 0.546475828
#     y: 0.737859726
#   }
#   relative_keypoints {
#     x: 0.398767
#     y: 0.533516109
#   }
#   relative_keypoints {
#     x: 0.663693905
#     y: 0.583723307
#   }
# }
# ]
# [label_id: 0
# score: 0.924235
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.37715885
#     ymin: 0.41111517
#     width: 0.318116397
#     height: 0.424130499
#   }
#   relative_keypoints {
#     x: 0.493264467
#     y: 0.530955
#   }
#   relative_keypoints {
#     x: 0.621107042
#     y: 0.557777941
#   }
#   relative_keypoints {
#     x: 0.55994153
#     y: 0.664312661
#   }
#   relative_keypoints {
#     x: 0.546475828
#     y: 0.737859726
#   }
#   relative_keypoints {
#     x: 0.398767
#     y: 0.533516109
#   }
#   relative_keypoints {
#     x: 0.663693905
#     y: 0.583723307
#   }
# }
# ]
# [label_id: 0
# score: 0.919513345
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.375853
#     ymin: 0.411362886
#     width: 0.320425868
#     height: 0.427208841
#   }
#   relative_keypoints {
#     x: 0.492630243
#     y: 0.534035385
#   }
#   relative_keypoints {
#     x: 0.621863425
#     y: 0.564405143
#   }
#   relative_keypoints {
#     x: 0.558401644
#     y: 0.673430204
#   }
#   relative_keypoints {
#     x: 0.543803692
#     y: 0.74529165
#   }
#   relative_keypoints {
#     x: 0.396697372
#     y: 0.529279649
#   }
#   relative_keypoints {
#     x: 0.664144516
#     y: 0.586381257
#   }
# }
# ]
# [label_id: 0
# score: 0.919513345
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.375853
#     ymin: 0.411362886
#     width: 0.320425868
#     height: 0.427208841
#   }
#   relative_keypoints {
#     x: 0.492630243
#     y: 0.534035385
#   }
#   relative_keypoints {
#     x: 0.621863425
#     y: 0.564405143
#   }
#   relative_keypoints {
#     x: 0.558401644
#     y: 0.673430204
#   }
#   relative_keypoints {
#     x: 0.543803692
#     y: 0.74529165
#   }
#   relative_keypoints {
#     x: 0.396697372
#     y: 0.529279649
#   }
#   relative_keypoints {
#     x: 0.664144516
#     y: 0.586381257
#   }
# }
# ]
# [label_id: 0
# score: 0.923869848
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.377399921
#     ymin: 0.406594276
#     width: 0.321332097
#     height: 0.428420365
#   }
#   relative_keypoints {
#     x: 0.497715235
#     y: 0.532007933
#   }
#   relative_keypoints {
#     x: 0.625944376
#     y: 0.557235658
#   }
#   relative_keypoints {
#     x: 0.567808747
#     y: 0.668839753
#   }
#   relative_keypoints {
#     x: 0.553603351
#     y: 0.740553856
#   }
#   relative_keypoints {
#     x: 0.398659587
#     y: 0.530006111
#   }
#   relative_keypoints {
#     x: 0.665083408
#     y: 0.576290369
#   }
# }
# ]
# [label_id: 0
# score: 0.923869848
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.377399921
#     ymin: 0.406594276
#     width: 0.321332097
#     height: 0.428420365
#   }
#   relative_keypoints {
#     x: 0.497715235
#     y: 0.532007933
#   }
#   relative_keypoints {
#     x: 0.625944376
#     y: 0.557235658
#   }
#   relative_keypoints {
#     x: 0.567808747
#     y: 0.668839753
#   }
#   relative_keypoints {
#     x: 0.553603351
#     y: 0.740553856
#   }
#   relative_keypoints {
#     x: 0.398659587
#     y: 0.530006111
#   }
#   relative_keypoints {
#     x: 0.665083408
#     y: 0.576290369
#   }
# }
# ]
# [label_id: 0
# score: 0.941088855
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.380196631
#     ymin: 0.412474215
#     width: 0.314312756
#     height: 0.419066429
#   }
#   relative_keypoints {
#     x: 0.494815052
#     y: 0.538107216
#   }
#   relative_keypoints {
#     x: 0.623835802
#     y: 0.55702281
#   }
#   relative_keypoints {
#     x: 0.566980362
#     y: 0.668842554
#   }
#   relative_keypoints {
#     x: 0.555464387
#     y: 0.738345325
#   }
#   relative_keypoints {
#     x: 0.397474974
#     y: 0.539983571
#   }
#   relative_keypoints {
#     x: 0.664839804
#     y: 0.574212074
#   }
# }
# ]
# [label_id: 0
# score: 0.941088855
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.380196631
#     ymin: 0.412474215
#     width: 0.314312756
#     height: 0.419066429
#   }
#   relative_keypoints {
#     x: 0.494815052
#     y: 0.538107216
#   }
#   relative_keypoints {
#     x: 0.623835802
#     y: 0.55702281
#   }
#   relative_keypoints {
#     x: 0.566980362
#     y: 0.668842554
#   }
#   relative_keypoints {
#     x: 0.555464387
#     y: 0.738345325
#   }
#   relative_keypoints {
#     x: 0.397474974
#     y: 0.539983571
#   }
#   relative_keypoints {
#     x: 0.664839804
#     y: 0.574212074
#   }
# }
# ]
# [label_id: 0
# score: 0.953114212
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.381656975
#     ymin: 0.412401199
#     width: 0.318031758
#     height: 0.424022019
#   }
#   relative_keypoints {
#     x: 0.493944645
#     y: 0.535685062
#   }
#   relative_keypoints {
#     x: 0.623502612
#     y: 0.562140942
#   }
#   relative_keypoints {
#     x: 0.558985889
#     y: 0.671140909
#   }
#   relative_keypoints {
#     x: 0.546597838
#     y: 0.740370572
#   }
#   relative_keypoints {
#     x: 0.402334392
#     y: 0.5323264
#   }
#   relative_keypoints {
#     x: 0.670947373
#     y: 0.582312167
#   }
# }
# ]
# [label_id: 0
# score: 0.953114212
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.381656975
#     ymin: 0.412401199
#     width: 0.318031758
#     height: 0.424022019
#   }
#   relative_keypoints {
#     x: 0.493944645
#     y: 0.535685062
#   }
#   relative_keypoints {
#     x: 0.623502612
#     y: 0.562140942
#   }
#   relative_keypoints {
#     x: 0.558985889
#     y: 0.671140909
#   }
#   relative_keypoints {
#     x: 0.546597838
#     y: 0.740370572
#   }
#   relative_keypoints {
#     x: 0.402334392
#     y: 0.5323264
#   }
#   relative_keypoints {
#     x: 0.670947373
#     y: 0.582312167
#   }
# }
# ]
# [label_id: 0
# score: 0.96867007
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.384033
#     ymin: 0.414887905
#     width: 0.312809318
#     height: 0.417065918
#   }
#   relative_keypoints {
#     x: 0.492097616
#     y: 0.53261447
#   }
#   relative_keypoints {
#     x: 0.619363129
#     y: 0.558300555
#   }
#   relative_keypoints {
#     x: 0.553851426
#     y: 0.662182868
#   }
#   relative_keypoints {
#     x: 0.541832566
#     y: 0.731901705
#   }
#   relative_keypoints {
#     x: 0.405205697
#     y: 0.533931315
#   }
#   relative_keypoints {
#     x: 0.670735359
#     y: 0.58545059
#   }
# }
# ]
# [label_id: 0
# score: 0.96867007
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.384033
#     ymin: 0.414887905
#     width: 0.312809318
#     height: 0.417065918
#   }
#   relative_keypoints {
#     x: 0.492097616
#     y: 0.53261447
#   }
#   relative_keypoints {
#     x: 0.619363129
#     y: 0.558300555
#   }
#   relative_keypoints {
#     x: 0.553851426
#     y: 0.662182868
#   }
#   relative_keypoints {
#     x: 0.541832566
#     y: 0.731901705
#   }
#   relative_keypoints {
#     x: 0.405205697
#     y: 0.533931315
#   }
#   relative_keypoints {
#     x: 0.670735359
#     y: 0.58545059
#   }
# }
# ]
# [label_id: 0
# score: 0.974263132
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.382394344
#     ymin: 0.415368795
#     width: 0.31575498
#     height: 0.420992911
#   }
#   relative_keypoints {
#     x: 0.490930796
#     y: 0.532865942
#   }
#   relative_keypoints {
#     x: 0.618144453
#     y: 0.555743
#   }
#   relative_keypoints {
#     x: 0.552477956
#     y: 0.660062492
#   }
#   relative_keypoints {
#     x: 0.541323662
#     y: 0.731697738
#   }
#   relative_keypoints {
#     x: 0.405800551
#     y: 0.539624631
#   }
#   relative_keypoints {
#     x: 0.671465695
#     y: 0.587082207
#   }
# }
# ]
# [label_id: 0
# score: 0.974263132
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.382394344
#     ymin: 0.415368795
#     width: 0.31575498
#     height: 0.420992911
#   }
#   relative_keypoints {
#     x: 0.490930796
#     y: 0.532865942
#   }
#   relative_keypoints {
#     x: 0.618144453
#     y: 0.555743
#   }
#   relative_keypoints {
#     x: 0.552477956
#     y: 0.660062492
#   }
#   relative_keypoints {
#     x: 0.541323662
#     y: 0.731697738
#   }
#   relative_keypoints {
#     x: 0.405800551
#     y: 0.539624631
#   }
#   relative_keypoints {
#     x: 0.671465695
#     y: 0.587082207
#   }
# }
# ]
# [label_id: 0
# score: 0.973392487
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.381816596
#     ymin: 0.414491951
#     width: 0.317742258
#     height: 0.423642397
#   }
#   relative_keypoints {
#     x: 0.49182725
#     y: 0.533859968
#   }
#   relative_keypoints {
#     x: 0.620281696
#     y: 0.554672539
#   }
#   relative_keypoints {
#     x: 0.555715203
#     y: 0.661126137
#   }
#   relative_keypoints {
#     x: 0.544804752
#     y: 0.733220279
#   }
#   relative_keypoints {
#     x: 0.404580146
#     y: 0.541602135
#   }
#   relative_keypoints {
#     x: 0.672636867
#     y: 0.584945917
#   }
# }
# ]
# [label_id: 0
# score: 0.973392487
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.381816596
#     ymin: 0.414491951
#     width: 0.317742258
#     height: 0.423642397
#   }
#   relative_keypoints {
#     x: 0.49182725
#     y: 0.533859968
#   }
#   relative_keypoints {
#     x: 0.620281696
#     y: 0.554672539
#   }
#   relative_keypoints {
#     x: 0.555715203
#     y: 0.661126137
#   }
#   relative_keypoints {
#     x: 0.544804752
#     y: 0.733220279
#   }
#   relative_keypoints {
#     x: 0.404580146
#     y: 0.541602135
#   }
#   relative_keypoints {
#     x: 0.672636867
#     y: 0.584945917
#   }
# }
# ]
# [label_id: 0
# score: 0.964497805
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.37894848
#     ymin: 0.411567628
#     width: 0.322311193
#     height: 0.429726958
#   }
#   relative_keypoints {
#     x: 0.486815542
#     y: 0.532500803
#   }
#   relative_keypoints {
#     x: 0.616193354
#     y: 0.550532341
#   }
#   relative_keypoints {
#     x: 0.550141573
#     y: 0.65879029
#   }
#   relative_keypoints {
#     x: 0.541377664
#     y: 0.733624637
#   }
#   relative_keypoints {
#     x: 0.403880686
#     y: 0.544218242
#   }
#   relative_keypoints {
#     x: 0.673142314
#     y: 0.581143677
#   }
# }
# ]
# [label_id: 0
# score: 0.964497805
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.37894848
#     ymin: 0.411567628
#     width: 0.322311193
#     height: 0.429726958
#   }
#   relative_keypoints {
#     x: 0.486815542
#     y: 0.532500803
#   }
#   relative_keypoints {
#     x: 0.616193354
#     y: 0.550532341
#   }
#   relative_keypoints {
#     x: 0.550141573
#     y: 0.65879029
#   }
#   relative_keypoints {
#     x: 0.541377664
#     y: 0.733624637
#   }
#   relative_keypoints {
#     x: 0.403880686
#     y: 0.544218242
#   }
#   relative_keypoints {
#     x: 0.673142314
#     y: 0.581143677
#   }
# }
# ]
# [label_id: 0
# score: 0.972371697
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.379022419
#     ymin: 0.413048089
#     width: 0.321137607
#     height: 0.428164244
#   }
#   relative_keypoints {
#     x: 0.483974248
#     y: 0.531625688
#   }
#   relative_keypoints {
#     x: 0.612906635
#     y: 0.550829887
#   }
#   relative_keypoints {
#     x: 0.545170248
#     y: 0.656796277
#   }
#   relative_keypoints {
#     x: 0.536982477
#     y: 0.731783926
#   }
#   relative_keypoints {
#     x: 0.404224604
#     y: 0.544718444
#   }
#   relative_keypoints {
#     x: 0.673256457
#     y: 0.5846228
#   }
# }
# ]
# [label_id: 0
# score: 0.972371697
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.379022419
#     ymin: 0.413048089
#     width: 0.321137607
#     height: 0.428164244
#   }
#   relative_keypoints {
#     x: 0.483974248
#     y: 0.531625688
#   }
#   relative_keypoints {
#     x: 0.612906635
#     y: 0.550829887
#   }
#   relative_keypoints {
#     x: 0.545170248
#     y: 0.656796277
#   }
#   relative_keypoints {
#     x: 0.536982477
#     y: 0.731783926
#   }
#   relative_keypoints {
#     x: 0.404224604
#     y: 0.544718444
#   }
#   relative_keypoints {
#     x: 0.673256457
#     y: 0.5846228
#   }
# }
# ]
# [label_id: 0
# score: 0.969404936
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.379312724
#     ymin: 0.410461366
#     width: 0.316337615
#     height: 0.421768546
#   }
#   relative_keypoints {
#     x: 0.482772052
#     y: 0.530471861
#   }
#   relative_keypoints {
#     x: 0.611543357
#     y: 0.545584619
#   }
#   relative_keypoints {
#     x: 0.546585798
#     y: 0.652029455
#   }
#   relative_keypoints {
#     x: 0.539252162
#     y: 0.725876331
#   }
#   relative_keypoints {
#     x: 0.402202487
#     y: 0.544490516
#   }
#   relative_keypoints {
#     x: 0.670998812
#     y: 0.575700104
#   }
# }
# ]
# [label_id: 0
# score: 0.969404936
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.379312724
#     ymin: 0.410461366
#     width: 0.316337615
#     height: 0.421768546
#   }
#   relative_keypoints {
#     x: 0.482772052
#     y: 0.530471861
#   }
#   relative_keypoints {
#     x: 0.611543357
#     y: 0.545584619
#   }
#   relative_keypoints {
#     x: 0.546585798
#     y: 0.652029455
#   }
#   relative_keypoints {
#     x: 0.539252162
#     y: 0.725876331
#   }
#   relative_keypoints {
#     x: 0.402202487
#     y: 0.544490516
#   }
#   relative_keypoints {
#     x: 0.670998812
#     y: 0.575700104
#   }
# }
# ]
# [label_id: 0
# score: 0.965550601
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.378083199
#     ymin: 0.408799469
#     width: 0.321035594
#     height: 0.428025484
#   }
#   relative_keypoints {
#     x: 0.482243121
#     y: 0.535033047
#   }
#   relative_keypoints {
#     x: 0.61328876
#     y: 0.541513383
#   }
#   relative_keypoints {
#     x: 0.552282929
#     y: 0.653599203
#   }
#   relative_keypoints {
#     x: 0.547548532
#     y: 0.728911
#   }
#   relative_keypoints {
#     x: 0.399977893
#     y: 0.554648817
#   }
#   relative_keypoints {
#     x: 0.673027158
#     y: 0.566960812
#   }
# }
# ]
# [label_id: 0
# score: 0.965550601
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.378083199
#     ymin: 0.408799469
#     width: 0.321035594
#     height: 0.428025484
#   }
#   relative_keypoints {
#     x: 0.482243121
#     y: 0.535033047
#   }
#   relative_keypoints {
#     x: 0.61328876
#     y: 0.541513383
#   }
#   relative_keypoints {
#     x: 0.552282929
#     y: 0.653599203
#   }
#   relative_keypoints {
#     x: 0.547548532
#     y: 0.728911
#   }
#   relative_keypoints {
#     x: 0.399977893
#     y: 0.554648817
#   }
#   relative_keypoints {
#     x: 0.673027158
#     y: 0.566960812
#   }
# }
# ]
# [label_id: 0
# score: 0.976158559
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.374264926
#     ymin: 0.404471397
#     width: 0.321406633
#     height: 0.428527534
#   }
#   relative_keypoints {
#     x: 0.480348021
#     y: 0.530779302
#   }
#   relative_keypoints {
#     x: 0.609668374
#     y: 0.534441411
#   }
#   relative_keypoints {
#     x: 0.550988495
#     y: 0.647405088
#   }
#   relative_keypoints {
#     x: 0.546116948
#     y: 0.722304106
#   }
#   relative_keypoints {
#     x: 0.397793293
#     y: 0.552650511
#   }
#   relative_keypoints {
#     x: 0.668544769
#     y: 0.561055899
#   }
# }
# ]
# [label_id: 0
# score: 0.976158559
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.374264926
#     ymin: 0.404471397
#     width: 0.321406633
#     height: 0.428527534
#   }
#   relative_keypoints {
#     x: 0.480348021
#     y: 0.530779302
#   }
#   relative_keypoints {
#     x: 0.609668374
#     y: 0.534441411
#   }
#   relative_keypoints {
#     x: 0.550988495
#     y: 0.647405088
#   }
#   relative_keypoints {
#     x: 0.546116948
#     y: 0.722304106
#   }
#   relative_keypoints {
#     x: 0.397793293
#     y: 0.552650511
#   }
#   relative_keypoints {
#     x: 0.668544769
#     y: 0.561055899
#   }
# }
# ]
# [label_id: 0
# score: 0.958485782
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.37640509
#     ymin: 0.404516757
#     width: 0.315165
#     height: 0.420199633
#   }
#   relative_keypoints {
#     x: 0.479718626
#     y: 0.527841806
#   }
#   relative_keypoints {
#     x: 0.608006895
#     y: 0.532429457
#   }
#   relative_keypoints {
#     x: 0.549927
#     y: 0.642231941
#   }
#   relative_keypoints {
#     x: 0.545577
#     y: 0.717678368
#   }
#   relative_keypoints {
#     x: 0.397535712
#     y: 0.551420689
#   }
#   relative_keypoints {
#     x: 0.665173
#     y: 0.558894217
#   }
# }
# ]
# [label_id: 0
# score: 0.958485782
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.37640509
#     ymin: 0.404516757
#     width: 0.315165
#     height: 0.420199633
#   }
#   relative_keypoints {
#     x: 0.479718626
#     y: 0.527841806
#   }
#   relative_keypoints {
#     x: 0.608006895
#     y: 0.532429457
#   }
#   relative_keypoints {
#     x: 0.549927
#     y: 0.642231941
#   }
#   relative_keypoints {
#     x: 0.545577
#     y: 0.717678368
#   }
#   relative_keypoints {
#     x: 0.397535712
#     y: 0.551420689
#   }
#   relative_keypoints {
#     x: 0.665173
#     y: 0.558894217
#   }
# }
# ]
# [label_id: 0
# score: 0.963420033
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.375828892
#     ymin: 0.40293026
#     width: 0.317845017
#     height: 0.423772275
#   }
#   relative_keypoints {
#     x: 0.476582021
#     y: 0.521308124
#   }
#   relative_keypoints {
#     x: 0.605124474
#     y: 0.522743523
#   }
#   relative_keypoints {
#     x: 0.545287371
#     y: 0.628393
#   }
#   relative_keypoints {
#     x: 0.542140901
#     y: 0.710068464
#   }
#   relative_keypoints {
#     x: 0.398044169
#     y: 0.555955
#   }
#   relative_keypoints {
#     x: 0.667879462
#     y: 0.559464514
#   }
# }
# ]
# [label_id: 0
# score: 0.963420033
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.375828892
#     ymin: 0.40293026
#     width: 0.317845017
#     height: 0.423772275
#   }
#   relative_keypoints {
#     x: 0.476582021
#     y: 0.521308124
#   }
#   relative_keypoints {
#     x: 0.605124474
#     y: 0.522743523
#   }
#   relative_keypoints {
#     x: 0.545287371
#     y: 0.628393
#   }
#   relative_keypoints {
#     x: 0.542140901
#     y: 0.710068464
#   }
#   relative_keypoints {
#     x: 0.398044169
#     y: 0.555955
#   }
#   relative_keypoints {
#     x: 0.667879462
#     y: 0.559464514
#   }
# }
# ]
# [label_id: 0
# score: 0.969696879
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.376082242
#     ymin: 0.40269053
#     width: 0.311854184
#     height: 0.415784419
#   }
#   relative_keypoints {
#     x: 0.476768762
#     y: 0.512650967
#   }
#   relative_keypoints {
#     x: 0.603548884
#     y: 0.515800476
#   }
#   relative_keypoints {
#     x: 0.545825958
#     y: 0.613624573
#   }
#   relative_keypoints {
#     x: 0.540637791
#     y: 0.698093414
#   }
#   relative_keypoints {
#     x: 0.39454
#     y: 0.552601576
#   }
#   relative_keypoints {
#     x: 0.662452161
#     y: 0.560956
#   }
# }
# ]
# [label_id: 0
# score: 0.969696879
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.376082242
#     ymin: 0.40269053
#     width: 0.311854184
#     height: 0.415784419
#   }
#   relative_keypoints {
#     x: 0.476768762
#     y: 0.512650967
#   }
#   relative_keypoints {
#     x: 0.603548884
#     y: 0.515800476
#   }
#   relative_keypoints {
#     x: 0.545825958
#     y: 0.613624573
#   }
#   relative_keypoints {
#     x: 0.540637791
#     y: 0.698093414
#   }
#   relative_keypoints {
#     x: 0.39454
#     y: 0.552601576
#   }
#   relative_keypoints {
#     x: 0.662452161
#     y: 0.560956
#   }
# }
# ]
# [label_id: 0
# score: 0.959118664
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.381716251
#     ymin: 0.399205029
#     width: 0.296322048
#     height: 0.39508456
#   }
#   relative_keypoints {
#     x: 0.472691685
#     y: 0.497417212
#   }
#   relative_keypoints {
#     x: 0.599421918
#     y: 0.501875699
#   }
#   relative_keypoints {
#     x: 0.539970934
#     y: 0.586331546
#   }
#   relative_keypoints {
#     x: 0.535816193
#     y: 0.672718048
#   }
#   relative_keypoints {
#     x: 0.393996477
#     y: 0.544646263
#   }
#   relative_keypoints {
#     x: 0.660231948
#     y: 0.554582775
#   }
# }
# ]
# [label_id: 0
# score: 0.959118664
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.381716251
#     ymin: 0.399205029
#     width: 0.296322048
#     height: 0.39508456
#   }
#   relative_keypoints {
#     x: 0.472691685
#     y: 0.497417212
#   }
#   relative_keypoints {
#     x: 0.599421918
#     y: 0.501875699
#   }
#   relative_keypoints {
#     x: 0.539970934
#     y: 0.586331546
#   }
#   relative_keypoints {
#     x: 0.535816193
#     y: 0.672718048
#   }
#   relative_keypoints {
#     x: 0.393996477
#     y: 0.544646263
#   }
#   relative_keypoints {
#     x: 0.660231948
#     y: 0.554582775
#   }
# }
# ]
# [label_id: 0
# score: 0.962149501
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.37090379
#     ymin: 0.38790375
#     width: 0.308766186
#     height: 0.411669612
#   }
#   relative_keypoints {
#     x: 0.46975565
#     y: 0.483689964
#   }
#   relative_keypoints {
#     x: 0.599847913
#     y: 0.492186546
#   }
#   relative_keypoints {
#     x: 0.53868264
#     y: 0.57481724
#   }
#   relative_keypoints {
#     x: 0.531867504
#     y: 0.668174446
#   }
#   relative_keypoints {
#     x: 0.384722888
#     y: 0.536640882
#   }
#   relative_keypoints {
#     x: 0.658813834
#     y: 0.55579263
#   }
# }
# ]
# [label_id: 0
# score: 0.962149501
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.37090379
#     ymin: 0.38790375
#     width: 0.308766186
#     height: 0.411669612
#   }
#   relative_keypoints {
#     x: 0.46975565
#     y: 0.483689964
#   }
#   relative_keypoints {
#     x: 0.599847913
#     y: 0.492186546
#   }
#   relative_keypoints {
#     x: 0.53868264
#     y: 0.57481724
#   }
#   relative_keypoints {
#     x: 0.531867504
#     y: 0.668174446
#   }
#   relative_keypoints {
#     x: 0.384722888
#     y: 0.536640882
#   }
#   relative_keypoints {
#     x: 0.658813834
#     y: 0.55579263
#   }
# }
# ]
# [label_id: 0
# score: 0.953085542
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.371370137
#     ymin: 0.383259535
#     width: 0.308558106
#     height: 0.411392152
#   }
#   relative_keypoints {
#     x: 0.467564017
#     y: 0.480428934
#   }
#   relative_keypoints {
#     x: 0.599517167
#     y: 0.486543596
#   }
#   relative_keypoints {
#     x: 0.537268043
#     y: 0.570054829
#   }
#   relative_keypoints {
#     x: 0.531635046
#     y: 0.663410485
#   }
#   relative_keypoints {
#     x: 0.383795977
#     y: 0.534792125
#   }
#   relative_keypoints {
#     x: 0.660977125
#     y: 0.549392164
#   }
# }
# ]
# [label_id: 0
# score: 0.953085542
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.371370137
#     ymin: 0.383259535
#     width: 0.308558106
#     height: 0.411392152
#   }
#   relative_keypoints {
#     x: 0.467564017
#     y: 0.480428934
#   }
#   relative_keypoints {
#     x: 0.599517167
#     y: 0.486543596
#   }
#   relative_keypoints {
#     x: 0.537268043
#     y: 0.570054829
#   }
#   relative_keypoints {
#     x: 0.531635046
#     y: 0.663410485
#   }
#   relative_keypoints {
#     x: 0.383795977
#     y: 0.534792125
#   }
#   relative_keypoints {
#     x: 0.660977125
#     y: 0.549392164
#   }
# }
# ]
# [label_id: 0
# score: 0.930675447
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.372633666
#     ymin: 0.392949581
#     width: 0.314314574
#     height: 0.419064939
#   }
#   relative_keypoints {
#     x: 0.466334194
#     y: 0.490084231
#   }
#   relative_keypoints {
#     x: 0.602936864
#     y: 0.490071833
#   }
#   relative_keypoints {
#     x: 0.538640499
#     y: 0.573820412
#   }
#   relative_keypoints {
#     x: 0.535771787
#     y: 0.674238682
#   }
#   relative_keypoints {
#     x: 0.383679837
#     y: 0.556433856
#   }
#   relative_keypoints {
#     x: 0.669812083
#     y: 0.558670342
#   }
# }
# ]
# [label_id: 0
# score: 0.930675447
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.372633666
#     ymin: 0.392949581
#     width: 0.314314574
# ...
#   }
#   relative_keypoints {
#     x: 0.652585447
#     y: 0.531022608
#   }
# }
# ]
# [label_id: 0
# score: 0.953613937
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.371800095
#     ymin: 0.382725596
#     width: 0.306772739
#     height: 0.409011483
#   }
#   relative_keypoints {
#     x: 0.476810455
#     y: 0.489323735
#   }
#   relative_keypoints {
#     x: 0.603440821
#     y: 0.496611118
#   }
#   relative_keypoints {
#     x: 0.549231291
#     y: 0.59060818
#   }
#   relative_keypoints {
#     x: 0.54109925
#     y: 0.674418
#   }
#   relative_keypoints {
#     x: 0.386814713
#     y: 0.526573241
#   }
#   relative_keypoints {
#     x: 0.653579772
#     y: 0.541111469
#   }
# }
# ]
# [label_id: 0
# score: 0.953613937
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.371800095
#     ymin: 0.382725596
#     width: 0.306772739
#     height: 0.409011483
#   }
#   relative_keypoints {
#     x: 0.476810455
#     y: 0.489323735
#   }
#   relative_keypoints {
#     x: 0.603440821
#     y: 0.496611118
#   }
#   relative_keypoints {
#     x: 0.549231291
#     y: 0.59060818
#   }
#   relative_keypoints {
#     x: 0.54109925
#     y: 0.674418
#   }
#   relative_keypoints {
#     x: 0.386814713
#     y: 0.526573241
#   }
#   relative_keypoints {
#     x: 0.653579772
#     y: 0.541111469
#   }
# }
# ]
# [label_id: 0
# score: 0.954286337
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.372600675
#     ymin: 0.381217062
#     width: 0.306614876
#     height: 0.40880096
#   }
#   relative_keypoints {
#     x: 0.475552619
#     y: 0.488232195
#   }
#   relative_keypoints {
#     x: 0.601928234
#     y: 0.495732546
#   }
#   relative_keypoints {
#     x: 0.545972168
#     y: 0.590388
#   }
#   relative_keypoints {
#     x: 0.538710535
#     y: 0.673409045
#   }
#   relative_keypoints {
#     x: 0.388875306
#     y: 0.52445966
#   }
#   relative_keypoints {
#     x: 0.654845655
#     y: 0.53937155
#   }
# }
# ]
# [label_id: 0
# score: 0.954286337
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.372600675
#     ymin: 0.381217062
#     width: 0.306614876
#     height: 0.40880096
#   }
#   relative_keypoints {
#     x: 0.475552619
#     y: 0.488232195
#   }
#   relative_keypoints {
#     x: 0.601928234
#     y: 0.495732546
#   }
#   relative_keypoints {
#     x: 0.545972168
#     y: 0.590388
#   }
#   relative_keypoints {
#     x: 0.538710535
#     y: 0.673409045
#   }
#   relative_keypoints {
#     x: 0.388875306
#     y: 0.52445966
#   }
#   relative_keypoints {
#     x: 0.654845655
#     y: 0.53937155
#   }
# }
# ]
# [label_id: 0
# score: 0.956284821
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.371807814
#     ymin: 0.381115377
#     width: 0.305472255
#     height: 0.407276154
#   }
#   relative_keypoints {
#     x: 0.473683149
#     y: 0.488768935
#   }
#   relative_keypoints {
#     x: 0.599922895
#     y: 0.498022676
#   }
#   relative_keypoints {
#     x: 0.54245764
#     y: 0.593336284
#   }
#   relative_keypoints {
#     x: 0.534919441
#     y: 0.674282074
#   }
#   relative_keypoints {
#     x: 0.387919575
#     y: 0.520563066
#   }
#   relative_keypoints {
#     x: 0.653616428
#     y: 0.539307833
#   }
# }
# ]
# [label_id: 0
# score: 0.956284821
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.371807814
#     ymin: 0.381115377
#     width: 0.305472255
#     height: 0.407276154
#   }
#   relative_keypoints {
#     x: 0.473683149
#     y: 0.488768935
#   }
#   relative_keypoints {
#     x: 0.599922895
#     y: 0.498022676
#   }
#   relative_keypoints {
#     x: 0.54245764
#     y: 0.593336284
#   }
#   relative_keypoints {
#     x: 0.534919441
#     y: 0.674282074
#   }
#   relative_keypoints {
#     x: 0.387919575
#     y: 0.520563066
#   }
#   relative_keypoints {
#     x: 0.653616428
#     y: 0.539307833
#   }
# }
# ]
# [label_id: 0
# score: 0.95514971
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.370797694
#     ymin: 0.382218242
#     width: 0.302980065
#     height: 0.403952539
#   }
#   relative_keypoints {
#     x: 0.472312093
#     y: 0.488198102
#   }
#   relative_keypoints {
#     x: 0.598997355
#     y: 0.497044861
#   }
#   relative_keypoints {
#     x: 0.542809904
#     y: 0.59028393
#   }
#   relative_keypoints {
#     x: 0.53524816
#     y: 0.67177844
#   }
#   relative_keypoints {
#     x: 0.384775311
#     y: 0.522428
#   }
#   relative_keypoints {
#     x: 0.650946915
#     y: 0.539346397
#   }
# }
# ]
# [label_id: 0
# score: 0.95514971
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.370797694
#     ymin: 0.382218242
#     width: 0.302980065
#     height: 0.403952539
#   }
#   relative_keypoints {
#     x: 0.472312093
#     y: 0.488198102
#   }
#   relative_keypoints {
#     x: 0.598997355
#     y: 0.497044861
#   }
#   relative_keypoints {
#     x: 0.542809904
#     y: 0.59028393
#   }
#   relative_keypoints {
#     x: 0.53524816
#     y: 0.67177844
#   }
#   relative_keypoints {
#     x: 0.384775311
#     y: 0.522428
#   }
#   relative_keypoints {
#     x: 0.650946915
#     y: 0.539346397
#   }
# }
# ]
# [label_id: 0
# score: 0.95634228
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.370536953
#     ymin: 0.382835329
#     width: 0.304209262
#     height: 0.405591
#   }
#   relative_keypoints {
#     x: 0.469858527
#     y: 0.48999685
#   }
#   relative_keypoints {
#     x: 0.596583366
#     y: 0.498098373
#   }
#   relative_keypoints {
#     x: 0.53847295
#     y: 0.592858374
#   }
#   relative_keypoints {
#     x: 0.531896234
#     y: 0.674187839
#   }
#   relative_keypoints {
#     x: 0.38571614
#     y: 0.5239
#   }
#   relative_keypoints {
#     x: 0.65182507
#     y: 0.540084183
#   }
# }
# ]
# [label_id: 0
# score: 0.95634228
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.370536953
#     ymin: 0.382835329
#     width: 0.304209262
#     height: 0.405591
#   }
#   relative_keypoints {
#     x: 0.469858527
#     y: 0.48999685
#   }
#   relative_keypoints {
#     x: 0.596583366
#     y: 0.498098373
#   }
#   relative_keypoints {
#     x: 0.53847295
#     y: 0.592858374
#   }
#   relative_keypoints {
#     x: 0.531896234
#     y: 0.674187839
#   }
#   relative_keypoints {
#     x: 0.38571614
#     y: 0.5239
#   }
#   relative_keypoints {
#     x: 0.65182507
#     y: 0.540084183
#   }
# }
# ]
# [label_id: 0
# score: 0.951806247
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.37116915
#     ymin: 0.38558954
#     width: 0.300774336
#     height: 0.401009202
#   }
#   relative_keypoints {
#     x: 0.468984038
#     y: 0.492757261
#   }
#   relative_keypoints {
#     x: 0.595475256
#     y: 0.497788846
#   }
#   relative_keypoints {
#     x: 0.539133
#     y: 0.5926103
#   }
#   relative_keypoints {
#     x: 0.533697128
#     y: 0.673730373
#   }
#   relative_keypoints {
#     x: 0.385151595
#     y: 0.529200733
#   }
#   relative_keypoints {
#     x: 0.650141537
#     y: 0.538466454
#   }
# }
# ]
# [label_id: 0
# score: 0.951806247
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.37116915
#     ymin: 0.38558954
#     width: 0.300774336
#     height: 0.401009202
#   }
#   relative_keypoints {
#     x: 0.468984038
#     y: 0.492757261
#   }
#   relative_keypoints {
#     x: 0.595475256
#     y: 0.497788846
#   }
#   relative_keypoints {
#     x: 0.539133
#     y: 0.5926103
#   }
#   relative_keypoints {
#     x: 0.533697128
#     y: 0.673730373
#   }
#   relative_keypoints {
#     x: 0.385151595
#     y: 0.529200733
#   }
#   relative_keypoints {
#     x: 0.650141537
#     y: 0.538466454
#   }
# }
# ]
# [label_id: 0
# score: 0.951866388
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.372608155
#     ymin: 0.384803832
#     width: 0.299783915
#     height: 0.399691343
#   }
#   relative_keypoints {
#     x: 0.468043655
#     y: 0.494314671
#   }
#   relative_keypoints {
#     x: 0.593963504
#     y: 0.498703659
#   }
#   relative_keypoints {
#     x: 0.53689605
#     y: 0.595040143
#   }
#   relative_keypoints {
#     x: 0.531989694
#     y: 0.673976
#   }
#   relative_keypoints {
#     x: 0.386573732
#     y: 0.527273655
#   }
#   relative_keypoints {
#     x: 0.650561512
#     y: 0.535969794
#   }
# }
# ]
# [label_id: 0
# score: 0.951866388
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.372608155
#     ymin: 0.384803832
#     width: 0.299783915
#     height: 0.399691343
#   }
#   relative_keypoints {
#     x: 0.468043655
#     y: 0.494314671
#   }
#   relative_keypoints {
#     x: 0.593963504
#     y: 0.498703659
#   }
#   relative_keypoints {
#     x: 0.53689605
#     y: 0.595040143
#   }
#   relative_keypoints {
#     x: 0.531989694
#     y: 0.673976
#   }
#   relative_keypoints {
#     x: 0.386573732
#     y: 0.527273655
#   }
#   relative_keypoints {
#     x: 0.650561512
#     y: 0.535969794
#   }
# }
# ]
# [label_id: 0
# score: 0.95427829
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.372760266
#     ymin: 0.379616559
#     width: 0.302358359
#     height: 0.403124332
#   }
#   relative_keypoints {
#     x: 0.469242752
#     y: 0.487779379
#   }
#   relative_keypoints {
#     x: 0.59434551
#     y: 0.495788753
#   }
#   relative_keypoints {
#     x: 0.53478986
#     y: 0.591568053
#   }
#   relative_keypoints {
#     x: 0.528997779
#     y: 0.670760214
#   }
#   relative_keypoints {
#     x: 0.38948682
#     y: 0.51849407
#   }
#   relative_keypoints {
#     x: 0.65233469
#     y: 0.53523916
#   }
# }
# ]
# [label_id: 0
# score: 0.95427829
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.372760266
#     ymin: 0.379616559
#     width: 0.302358359
#     height: 0.403124332
#   }
#   relative_keypoints {
#     x: 0.469242752
#     y: 0.487779379
#   }
#   relative_keypoints {
#     x: 0.59434551
#     y: 0.495788753
#   }
#   relative_keypoints {
#     x: 0.53478986
#     y: 0.591568053
#   }
#   relative_keypoints {
#     x: 0.528997779
#     y: 0.670760214
#   }
#   relative_keypoints {
#     x: 0.38948682
#     y: 0.51849407
#   }
#   relative_keypoints {
#     x: 0.65233469
#     y: 0.53523916
#   }
# }
# ]
# [label_id: 0
# score: 0.951375484
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.371233165
#     ymin: 0.376777232
#     width: 0.302497387
#     height: 0.403307319
#   }
#   relative_keypoints {
#     x: 0.469323
#     y: 0.487354696
#   }
#   relative_keypoints {
#     x: 0.593865097
#     y: 0.493904173
#   }
#   relative_keypoints {
#     x: 0.536312
#     y: 0.591888368
#   }
#   relative_keypoints {
#     x: 0.530630589
#     y: 0.67011112
#   }
#   relative_keypoints {
#     x: 0.388593644
#     y: 0.51715368
#   }
#   relative_keypoints {
#     x: 0.650284171
#     y: 0.530078888
#   }
# }
# ]
# [label_id: 0
# score: 0.951375484
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.371233165
#     ymin: 0.376777232
#     width: 0.302497387
#     height: 0.403307319
#   }
#   relative_keypoints {
#     x: 0.469323
#     y: 0.487354696
#   }
#   relative_keypoints {
#     x: 0.593865097
#     y: 0.493904173
#   }
#   relative_keypoints {
#     x: 0.536312
#     y: 0.591888368
#   }
#   relative_keypoints {
#     x: 0.530630589
#     y: 0.67011112
#   }
#   relative_keypoints {
#     x: 0.388593644
#     y: 0.51715368
#   }
#   relative_keypoints {
#     x: 0.650284171
#     y: 0.530078888
#   }
# }
# ]
# [label_id: 0
# score: 0.951237082
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.371011913
#     ymin: 0.378906727
#     width: 0.302649617
#     height: 0.403510571
#   }
#   relative_keypoints {
#     x: 0.471039504
#     y: 0.488291502
#   }
#   relative_keypoints {
#     x: 0.595828176
#     y: 0.496465981
#   }
#   relative_keypoints {
#     x: 0.538725495
#     y: 0.592836678
#   }
#   relative_keypoints {
#     x: 0.531926334
#     y: 0.671652377
#   }
#   relative_keypoints {
#     x: 0.387548983
#     y: 0.518318832
#   }
#   relative_keypoints {
#     x: 0.650073707
#     y: 0.534253836
#   }
# }
# ]
# [label_id: 0
# score: 0.951237082
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.371011913
#     ymin: 0.378906727
#     width: 0.302649617
#     height: 0.403510571
#   }
#   relative_keypoints {
#     x: 0.471039504
#     y: 0.488291502
#   }
#   relative_keypoints {
#     x: 0.595828176
#     y: 0.496465981
#   }
#   relative_keypoints {
#     x: 0.538725495
#     y: 0.592836678
#   }
#   relative_keypoints {
#     x: 0.531926334
#     y: 0.671652377
#   }
#   relative_keypoints {
#     x: 0.387548983
#     y: 0.518318832
#   }
#   relative_keypoints {
#     x: 0.650073707
#     y: 0.534253836
#   }
# }
# ]
# [label_id: 0
# score: 0.953991771
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.372400194
#     ymin: 0.37945348
#     width: 0.300242037
#     height: 0.400300682
#   }
#   relative_keypoints {
#     x: 0.4696922
#     y: 0.488987148
#   }
#   relative_keypoints {
#     x: 0.594840825
#     y: 0.493153334
#   }
#   relative_keypoints {
#     x: 0.538573265
#     y: 0.589430153
#   }
#   relative_keypoints {
#     x: 0.533337235
#     y: 0.668391228
#   }
#   relative_keypoints {
#     x: 0.387510091
#     y: 0.522480965
#   }
#   relative_keypoints {
#     x: 0.650553346
#     y: 0.530510128
#   }
# }
# ]
# [label_id: 0
# score: 0.953991771
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.372400194
#     ymin: 0.37945348
#     width: 0.300242037
#     height: 0.400300682
#   }
#   relative_keypoints {
#     x: 0.4696922
#     y: 0.488987148
#   }
#   relative_keypoints {
#     x: 0.594840825
#     y: 0.493153334
#   }
#   relative_keypoints {
#     x: 0.538573265
#     y: 0.589430153
#   }
#   relative_keypoints {
#     x: 0.533337235
#     y: 0.668391228
#   }
#   relative_keypoints {
#     x: 0.387510091
#     y: 0.522480965
#   }
#   relative_keypoints {
#     x: 0.650553346
#     y: 0.530510128
#   }
# }
# ]
# [label_id: 0
# score: 0.94623822
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.374224722
#     ymin: 0.385958254
#     width: 0.296505034
#     height: 0.395320296
#   }
#   relative_keypoints {
#     x: 0.469696343
#     y: 0.492576957
#   }
#   relative_keypoints {
#     x: 0.593877375
#     y: 0.497437119
#   }
#   relative_keypoints {
#     x: 0.537783265
#     y: 0.590757549
#   }
#   relative_keypoints {
#     x: 0.532522678
#     y: 0.670052528
#   }
#   relative_keypoints {
#     x: 0.388311386
#     y: 0.527329147
#   }
#   relative_keypoints {
#     x: 0.649236262
#     y: 0.536733687
#   }
# }
# ]
# [label_id: 0
# score: 0.94623822
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.374224722
#     ymin: 0.385958254
#     width: 0.296505034
#     height: 0.395320296
#   }
#   relative_keypoints {
#     x: 0.469696343
#     y: 0.492576957
#   }
#   relative_keypoints {
#     x: 0.593877375
#     y: 0.497437119
#   }
#   relative_keypoints {
#     x: 0.537783265
#     y: 0.590757549
#   }
#   relative_keypoints {
#     x: 0.532522678
#     y: 0.670052528
#   }
#   relative_keypoints {
#     x: 0.388311386
#     y: 0.527329147
#   }
#   relative_keypoints {
#     x: 0.649236262
#     y: 0.536733687
#   }
# }
# ]
# [label_id: 0
# score: 0.948201656
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.371399254
#     ymin: 0.379343808
#     width: 0.301384419
#     height: 0.401823401
#   }
#   relative_keypoints {
#     x: 0.471251279
#     y: 0.490505934
#   }
#   relative_keypoints {
#     x: 0.59542793
#     y: 0.496350586
#   }
#   relative_keypoints {
#     x: 0.539856911
#     y: 0.594679534
#   }
#   relative_keypoints {
#     x: 0.533692
#     y: 0.67219
#   }
#   relative_keypoints {
#     x: 0.387814224
#     y: 0.519495428
#   }
#   relative_keypoints {
#     x: 0.64885962
#     y: 0.530632794
#   }
# }
# ]
# [label_id: 0
# score: 0.948201656
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.371399254
#     ymin: 0.379343808
#     width: 0.301384419
#     height: 0.401823401
#   }
#   relative_keypoints {
#     x: 0.471251279
#     y: 0.490505934
#   }
#   relative_keypoints {
#     x: 0.59542793
#     y: 0.496350586
#   }
#   relative_keypoints {
#     x: 0.539856911
#     y: 0.594679534
#   }
#   relative_keypoints {
#     x: 0.533692
#     y: 0.67219
#   }
#   relative_keypoints {
#     x: 0.387814224
#     y: 0.519495428
#   }
#   relative_keypoints {
#     x: 0.64885962
#     y: 0.530632794
#   }
# }
# ]
# [label_id: 0
# score: 0.954587221
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.371971875
#     ymin: 0.38454473
#     width: 0.298279971
#     height: 0.397685111
#   }
#   relative_keypoints {
#     x: 0.473351032
#     y: 0.489988685
#   }
#   relative_keypoints {
#     x: 0.597377062
#     y: 0.497808933
#   }
#   relative_keypoints {
#     x: 0.543160737
#     y: 0.59022
#   }
#   relative_keypoints {
#     x: 0.535612464
#     y: 0.670072734
#   }
#   relative_keypoints {
#     x: 0.386313051
#     y: 0.523402691
#   }
#   relative_keypoints {
#     x: 0.647694528
#     y: 0.538449466
#   }
# }
# ]
