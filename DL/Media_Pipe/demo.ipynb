# %%
import cv2

# %%
video=cv2.VideoCapture(0)
while True:
    succ,img=video.read()

    cv2.imshow('Webcam',img)
    if cv2.waitKey(1) & 0XFF==ord('q'):
        break
video.release()
cv2.destroyAllWindows()
