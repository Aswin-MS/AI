# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
x=[2000,2400,2700,3000,3400,3600,4000]
y=[5600000,6000000,6300000,6700000,7100000,7300000,7600000]

# %%
plt.scatter(x,y)
plt.yticks
plt.title('House Price Based on Area')
plt.xlabel('Area')
plt.ylabel('Price(lakhs)')
# Out:
# Text(0, 0.5, 'Price(lakhs)')
